# %%
# Import required libraries
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
from mne.viz import plot_topomap
import mne

# Load the sample EEG data
eeg_data = loadmat('sampleEEGdata.mat')
eeg = eeg_data['EEG']
eeg_times = eeg['times'][0][0].T

# Compute the ERP of each channel
# (remember that the ERP is the time-domain average across all trials at each time point)
erp = np.mean(eeg['data'][0][0], axis=2)

# %%
eeg['times'][0][0].T.shape
# Out:
# (640, 1)

# %%
chan2plot = 'fcz'
chanlocs = []
for i in eeg['chanlocs'][0][0]['labels'][0]:
    chanlocs.append(i[0].lower())
chanlocs = np.array(chanlocs)

chan_idx = np.where(chanlocs == chan2plot)[0][0]

plt.figure(figsize=(10,6))
plt.plot(eeg_times, erp[chan_idx], linewidth=2)
plt.xlabel('Time (ms)'), plt.ylabel('Activity (uV)')
plt.xlim([-400, 1200])
# Out:
# (-400.0, 1200.0)

# %%
eeg_chanlocs = []
for i in range(64):
    local_chanloc = []
    x = list(eeg['chanlocs'][0][0][0][i])
    th = x[1][0][0]
    rd = x[2][0][0]
    
    th = np.pi / 180 * th #convert degrees to radians
    
    th, rd = pol2cart(th,rd)
    eeg_chanlocs.append([th,rd])

eeg_chanlocs = np.array(eeg_chanlocs)
eeg_chanlocs = normalize_arr(eeg_chanlocs)

# ch_names = []
# ch_locations = []
# for i in range(64):
#     local_chanloc = []
#     clc = list(eeg['chanlocs'][0][0][0][i])
#     x = clc[3][0][0]
#     y = clc[4][0][0]
#     z = clc[5][0][0]
#     ch_locations.append([x,y,z])
    
#     ch_names.append(clc[0][0])
    
# Create a dummy Info object
info = mne.create_info(ch_names=ch_names, sfreq=256, ch_types='eeg')
# Set the channel locations
for ch_name, ch_loc in zip(ch_names, ch_locations):
    info['chs'][info['ch_names'].index(ch_name)]['loc'][:3] = ch_loc
# Create 2D layout
layout = mne.channels.make_eeg_layout(info)
# Extract 2D positions
pos2d = layout.pos[:, :2]

# Plot topographical maps
time2plot = 300 # in ms
# convert time in ms to time in indices
tidx = np.argmin(np.abs(eeg_times - time2plot))

fig, ax = plt.subplots(figsize=(8,8))
im, _ = plot_topomap(erp[:, tidx], pos2d, axes=ax, show=False, 
                     cmap='RdBu_r', ch_type='eeg',
                    contours=6)
plt.colorbar(im)

# Add a title
plt.title('ERP from {} ms'.format(time2plot))
plt.show()

# %%
def pol2cart(theta, rho):
    x = rho * np.cos(theta)
    y = rho * np.sin(theta)
    return x, y

eeg_chanlocs = []
for i in range(64):
    local_chanloc = []
    x = list(eeg['chanlocs'][0][0][0][i])
    th = x[1][0][0]
    rd = x[2][0][0]
    
    th = np.pi / 180 * th #convert degrees to radians
    
    th, rd = pol2cart(th,rd)
    eeg_chanlocs.append([th,rd])

eeg_chanlocs = np.array(eeg_chanlocs)
eeg_chanlocs

def normalize_arr(arr):
    # calculate the maximum absolute value in the array
    max_val = np.max(np.abs(arr))

    # normalize the array
    normalized_arr = arr / max_val

    # multiply the array by 2 and subtract 1 to make each element between -1 and 1
    normalized_arr = normalized_arr * 2 - 1
    
    return normalized_arr


print(normalize_arr(eeg_chanlocs))
# Out:
# [[ 0.54692555 -1.50041866]
#  [ 0.33592584 -1.96676479]
#  [ 0.22866911 -1.50795187]
#  [-0.19211105 -1.35116276]
#  [-0.16596862 -1.69852174]
#  [-0.11336405 -2.03463863]
#  [-0.01800172 -2.3472978 ]
#  [-0.47962006 -2.59663275]
#  [-0.54510842 -2.20587204]
#  [-0.57878216 -1.80657239]
#  [-0.59500061 -1.40394049]
#  [-1.         -1.42048584]
#  [-1.         -1.84195387]
#  [-1.         -2.26250987]
#  [-1.         -2.68329387]
#  [-1.52037994 -2.59663275]
#  [-1.45489158 -2.20587204]
#  [-1.42121784 -1.80657239]
#  [-1.40499939 -1.40394049]
#  [-1.80788895 -1.35116276]
#  [-1.83403138 -1.69852174]
#  [-1.88663595 -2.03463863]
#  [-1.98199828 -2.3472978 ]
#  [-2.24528899 -2.67147469]
#  [-2.33592584 -1.96676479]
#  [-2.22866911 -1.50795187]
#  [-2.54692555 -1.50041866]
#  [-3.         -1.        ]
#  [-2.59964922 -1.        ]
#  [-2.1995089  -1.        ]
#  [-1.79992984 -1.        ]
#  [-1.39975445 -1.        ]
#  [ 0.59964922 -1.        ]
#  [ 0.54692555 -0.49958134]
#  [ 0.33644244 -0.03406923]
#  [ 0.22866911 -0.49204813]
#  [ 0.1995089  -1.        ]
#  [-0.20007016 -1.        ]
#  [-0.1928188  -0.64914488]
#  [-0.16558811 -0.3023976 ]
#  [-0.11400317  0.03389282]
#  [-0.01695138  0.34646647]
#  [-0.47962006  0.59663275]
#  [-0.54510842  0.20587204]
#  [-0.57878216 -0.19342761]
#  [-0.59500061 -0.59605951]
#  [-0.60024555 -1.        ]
#  [-1.         -1.        ]
#  [-1.         -0.57858458]
#  [-1.         -0.15811629]
#  [-1.          0.26250987]
#  [-1.          0.68329387]
#  [-1.52190146  0.59609915]
#  [-1.45489158  0.20587204]
#  [-1.42121784 -0.19342761]
#  [-1.40499939 -0.59605951]
#  [-1.8071812  -0.64914488]
#  [-1.83441189 -0.3023976 ]
#  [-1.88599683  0.03389282]
#  [-1.98304862  0.34646647]
#  [-2.24528899  0.67147469]
#  [-2.33644244 -0.03406923]
#  [-2.22866911 -0.49204813]
#  [-2.54692555 -0.49958134]]

# %%
layout.pos[:, [1,2]]
# Out:
# array([[0.58393009, 0.06682268],
#        [0.692726  , 0.06682268],
#        [0.58568754, 0.06682268],
#        [0.54910953, 0.06682268],
#        [0.63014642, 0.06682268],
#        [0.70856058, 0.06682268],
#        [0.78150219, 0.06682268],
#        [0.83967062, 0.06682268],
#        [0.74850836, 0.06682268],
#        [0.65535402, 0.06682268],
#        [0.56142228, 0.06682268],
#        [0.56528222, 0.06682268],
#        [0.66360832, 0.06682268],
#        [0.76172165, 0.06682268],
#        [0.85988817, 0.06682268],
#        [0.83967062, 0.06682268],
#        [0.74850836, 0.06682268],
#        [0.65535402, 0.06682268],
#        [0.56142228, 0.06682268],
#        [0.54910953, 0.06682268],
#        [0.63014642, 0.06682268],
#        [0.70856058, 0.06682268],
#        [0.78150219, 0.06682268],
#        [0.85713082, 0.06682268],
#        [0.692726  , 0.06682268],
#        [0.58568754, 0.06682268],
#        [0.58393009, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.35044042, 0.06682268],
#        [0.24183908, 0.06682268],
#        [0.34868296, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.38533274, 0.06682268],
#        [0.30443857, 0.06682268],
#        [0.22598392, 0.06682268],
#        [0.15306226, 0.06682268],
#        [0.09469988, 0.06682268],
#        [0.18586214, 0.06682268],
#        [0.27901649, 0.06682268],
#        [0.37294823, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.46718525, 0.06682268],
#        [0.36887143, 0.06682268],
#        [0.27077856, 0.06682268],
#        [0.17264886, 0.06682268],
#        [0.07448234, 0.06682268],
#        [0.09482437, 0.06682268],
#        [0.18586214, 0.06682268],
#        [0.27901649, 0.06682268],
#        [0.37294823, 0.06682268],
#        [0.38533274, 0.06682268],
#        [0.30443857, 0.06682268],
#        [0.22598392, 0.06682268],
#        [0.15306226, 0.06682268],
#        [0.07723969, 0.06682268],
#        [0.24183908, 0.06682268],
#        [0.34868296, 0.06682268],
#        [0.35044042, 0.06682268]])
